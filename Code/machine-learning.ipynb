# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Create Path
df_path = Path('../Resources/clean_data.csv')

# %%
# Read in csv
df = pd.read_csv(df_path)
df
# Out:
#         Unnamed: 0  bed  bath  acre_lot              city        state  \
# 0                0  3.0   2.0      0.12          Adjuntas  Puerto Rico
# 1                1  4.0   2.0      0.08          Adjuntas  Puerto Rico
# 2                2  2.0   1.0      0.15        Juana Diaz  Puerto Rico
# 3                3  4.0   2.0      0.10             Ponce  Puerto Rico
# 4                5  4.0   3.0      0.46     San Sebastian  Puerto Rico
# ...            ...  ...   ...       ...               ...          ...
# 488206     1104658  3.0   3.0      0.23        Massapequa     New York
# 488207     1104660  4.0   3.0      0.14       East Meadow     New York
# 488208     1104661  2.0   2.0      0.06     New York City     New York
# 488209     1104663  5.0   4.0      0.08        Long Beach     New York
# 488210     1104664  3.0   3.0      0.14  Rockville Centre     New York
#
#         zip_code  house_size      price
# 0          601.0       920.0   105000.0
# ...
